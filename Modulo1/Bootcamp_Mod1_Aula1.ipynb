# %% [markdown]
# **Analisando Dados da Saúde com Python e Pandas**

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/A005012189_28_143_208.csv", encoding="ISO-8859-1",
                    skiprows = 3, sep=";", skipfooter=12,
                    thousands=".", decimal=",")

dados.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#   Unidade da Federação     2008/Jan  ...     2021/Mar         Total
# 0          11 Rondônia   1388528.39  ...  11023309.47  9.964113e+08
# 1              12 Acre    902416.00  ...   4077045.92  4.500485e+08
# 2          13 Amazonas   4735529.42  ...  22032176.22  1.917248e+09
# 3           14 Roraima    657889.53  ...   3985530.08  3.288770e+08
# 4              15 Pará  18864744.11  ...  33276392.89  4.705309e+09
#
# [5 rows x 161 columns]

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados['2008/Jan']
# Out:
# 0     1388528.39
# 1      902416.00
# 2     4735529.42
# 3      657889.53
# 4    18864744.11
# 5     1120973.34
# 6     3441592.69
# 7    10723506.39
# 8     7985142.43
# 9    15539821.90
# 10    5947814.08
# 11   10723002.45
# 12   14393949.89
# 13    6243726.32
# 14    2780750.11
# 15   21211522.47
# 16   45671659.76
# 17    5456723.98
# 18   23025258.52
# 19   91678473.48
# 20   38266347.46
# 21   16504913.45
# 22   30931325.46
# 23    5377392.11
# 24    4795299.01
# 25   15310637.29
# 26    4745919.19
# Name: 2008/Jan, dtype: float64

# %% [markdown]
# **Aula 1 -Vídeo 2**

# %%
dados.plot(x='Unidade da Federação', y='2008/Ago')

# %%
dados.plot(x='Unidade da Federação', y='2008/Ago', kind='bar', figsize=(10,7))

# %% [markdown]
# Desafio 01 - Escolher um título mais descritivo, que passe a mensagem adequada ao gráfico de barras.
#
# Desafio 02: Faça a mesma análise realizada em aula, porém para o mês mais recente.

# %%
ax = dados.plot(x = "Unidade da Federação", y="2008/Ago", kind="bar", title="Valores gastos com atendimentos hospitalares por estado em Ago/2008", figsize=(10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("R$ {x:,.2f}"))
ax.set_xlabel("")


plt.show()

# %%
ax = dados.plot(x = "Unidade da Federação", y="2021/Mar", kind="bar", title="Valores gastos com atendimentos hospitalares por estado em Mar/2021", figsize=(10,7), color="g")
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("R$ {x:,.2f}"))
ax.set_xlabel("")


plt.show()
